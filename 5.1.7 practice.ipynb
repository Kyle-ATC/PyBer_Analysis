# %%
import matplotlib.pyplot as plt

# %%
x = [24, 234, 2342, 34, 453, 22, 355, 575, 332, 5]
y = [5, 7, 3,3432, 345 , 332, 436, 47, 33, 22]

# %%
plt.scatter(x,y, c=('yellow', 'blue', 'orange','green','black','yellow', 'blue', 'orange','green','black'), marker='P', s=x)
plt.title("go a go")
plt.xlabel('examples')
plt.ylabel('double dependent')
plt.savefig("/Users/kylesherry/Desktop/Analytics_Bootcamp/Module_5_Matplotlib/scatplot.png")
plt.show()
